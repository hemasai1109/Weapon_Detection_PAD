# %% [markdown]
# <a href="https://colab.research.google.com/github/hemasai1109/Weapon_Detection_PAD/blob/main/Weapon_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Arijit1080/Licence-Plate-Detection-using-YOLO-V8.git
# Out:
# Cloning into 'Licence-Plate-Detection-using-YOLO-V8'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 133 (delta 4), reused 8 (delta 3), pack-reused 117
# Receiving objects: 100% (133/133), 14.73 MiB | 9.19 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
cd /content/Weapon_Detection
# Out:
# /content/Weapon Detection

# %%
ls
# Out:
# Image-Labelling-3/                                   predict.log       runs/      ultralytics/
# infantryman-Serbian-Greece-Salonika-April-1916.webp  requirements.txt  train.log  yolov8n.pt

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="YKa0VQRzjNoixdEDCYCl")
# project = rf.workspace("rapidev-pmcmr").project("image-labelling-uhngw")
# version = project.version(3)
# dataset = version.download("yolov8")

# %%
#!pip install -r requirements.txt

# %%
# !python /content/Weapon_Detection/ultralytics/yolo/v8/detect/train.py model=yolov8n.pt data=/content/Weapon_Detection/Image-Labelling-3/data.yaml epochs=100
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 126MB/s]
#
# ...

# %%
# !python /content/Weapon_Detection/ultralytics/yolo/v8/detect/predict.py model='/content/Weapon_Detection/runs/detect/train/weights/best.pt' source='/content/Weapon_Detection/infantryman-Serbian-Greece-Salonika-April-1916.webp'
# Out:
# 2024-03-17 05:59:47.762906: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 05:59:47.762956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 05:59:47.764468: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-17 05:59:49.056488: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# ...

# %%
# !python /content/Weapon_Detection/ultralytics/yolo/v8/detect/predict.py model='/content/Weapon_Detection/runs/detect/train/weights/best.pt' source="/content/Weapon_Detection/Pisto_Video.mp4"
# Out:
# 2024-03-17 06:07:34.197759: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-17 06:07:34.197815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-17 06:07:34.199143: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-17 06:07:35.436141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r Weapon_Detection.zip /content/Weapon_Detection/
# Out:
#   adding: content/Weapon_Detection/ (stored 0%)
#   adding: content/Weapon_Detection/.git/ (stored 0%)
#   adding: content/Weapon_Detection/.git/hooks/ (stored 0%)
#   adding: content/Weapon_Detection/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/Weapon_Detection/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/Weapon_Detection/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/Weapon_Detection/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/Weapon_Detection/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/Weapon_Detection/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/Weapon_Detection/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/Weapon_Detection/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/Weapon_Detection/.git/hooks/pre-rebase.sample (deflated 59%)
# ...

# %%
from google.colab import files
files.download('Weapon_Detection.zip')
